# %%
import pandas as pd

# %%
path = ('./IART_10_classification.xlsx')
xl = pd.ExcelFile(path, )
for i in xl.sheet_names:
    print(i)
# Out:
# car sales-historical data
# car sales-prospects
# credit
# telemarketing

# %%
x
